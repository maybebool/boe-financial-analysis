# %%
#project setup — run first, do not edit except NAME 
NAME = "rachel" # <<< your name

import sys, subprocess, pathlib
IN_COLAB = "google.colab" in sys.modules
REPO = "boe-financial-analysis"

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive", force_remount=False)
    if not pathlib.Path(f"/content/{REPO}").exists():
        subprocess.run(["git", "clone", "-q",
                        f"https://github.com/maybebool/{REPO}.git",
                        f"/content/{REPO}"], check=True)
    ROOT = pathlib.Path(f"/content/{REPO}")
    DATA = pathlib.Path("/content/drive/MyDrive/boe-data")
else:
    ROOT = pathlib.Path.cwd()
    while not (ROOT / "requirements.txt").exists() and ROOT != ROOT.parent:
        ROOT = ROOT.parent
    DATA = ROOT / "data"

sys.path.insert(0, str(ROOT))
subprocess.run(["git", "-C", str(ROOT), "fetch", "-q", "origin"], check=False)
subprocess.run(["git", "-C", str(ROOT), "merge", "-q", "origin/main", "-m", "sync"],
               check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r",
                str(ROOT / "requirements.txt")], check=True)

from notebooks.env_cell import verify, check_python
check_python()
try:
    verify(ROOT)
except RuntimeError as e:
    print(e)
    print("\n Runtime -> Restart session, then run this cell again.")
    raise

import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from src import loading

print(f"ok  python {sys.version.split()[0]}  pandas {pd.__version__}  data {DATA}")
# Out:
# WARNING: python 3.12, this project assumes 3.13
# ok  python 3.12.13  pandas 2.2.3  data /Users/rdrobinson/Cambridge/boe-financial-analysis/data

# %%
EXPORT = "2026-09-13"  # pin the export this notebook was written against

utt = loading.load(DATA, "all_utterances.csv", EXPORT)
sent = loading.load(DATA, "all_sentences.csv", EXPORT)
met = loading.load(DATA, "all_metrics.csv", EXPORT)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 EXPORT = "2026-09-13"  # pin the export this notebook was written against
#       2
# ----> 3 utt = loading.load(DATA, "all_utterances.csv", EXPORT)
#       4 sent = loading.load(DATA, "all_sentences.csv", EXPORT)
#       5 met = loading.load(DATA, "all_metrics.csv", EXPORT)
#
# File ~/Cambridge/boe-financial-analysis/src/loading.py:97, in load(data_dir, filename, export, firm)
#      89 def load(data_dir: pathlib.Path, filename: str, export: str = LATEST,
#      90          firm: str | None = None) -> pd.DataFrame:
#      91     """Load one CSV out of one export.
#      92
#      93     Leave `firm` out for the combined `all_*.csv` files. Pass a bank name to
#      94     reach a single document inside that bank's folder. Pin `export` to a date
#      95     so a rerun of this notebook gives the same numbers.
#      96     """
# ---> 97     folder = resolve(data_dir, export, firm)
#      98     path = folder / filename
#      99     if not path.exists():
#
# File ~/Cambridge/boe-financial-analysis/src/loading.py:51, in resolve(data_dir, export, firm)
#      48 def resolve(data_dir: pathlib.Path, export: str,
#      49             firm: str | None = None) -> pathlib.Path:
#      50     """Turn an export date, and optionally a bank, into a concrete folder."""
# ---> 51     known = exports(data_dir)
#      52     if not known:
#      53         raise FileNotFoundError(
#      54             f"[CONTRACT] no dated export folder in {_results_dir(data_dir)}."
#      55         )
#
# File ~/Cambridge/boe-financial-analysis/src/loading.py:45, in exports(data_dir)
#      43 def exports(data_dir: pathlib.Path) -> list[str]:
#      44     """Export dates available, oldest first."""
# ---> 45     return sorted(p.name for p in _results_dir(data_dir).iterdir() if p.is_dir())
#
# File ~/Cambridge/boe-financial-analysis/src/loading.py:35, in _results_dir(data_dir)
#      33 folder = data_dir / RESULTS
#      34 if not folder.exists():
# ---> 35     raise FileNotFoundError(
#      36         f"[CONTRACT] folder not found: {folder}. "
#      37         "In Colab, check that Drive is mounted and that 'boe-data' is in "
#      38         "My Drive (Shared with me, right click, Organise, Add shortcut)."
#      39     )
#      40 return folder
#
# FileNotFoundError: [CONTRACT] folder not found: /Users/rdrobinson/Cambridge/boe-financial-analysis/data/results. In Colab, check that Drive is mounted and that 'boe-data' is in My Drive (Shared with me, right click, Organise, Add shortcut).
