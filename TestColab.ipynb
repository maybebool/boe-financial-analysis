# %% [markdown]
# <a href="https://colab.research.google.com/github/maybebool/boe-financial-analysis/blob/inessa/TestColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# project setup - run first, do not edit except NAME
NAME = "inessa"  # <<< your name

import sys, subprocess, pathlib
IN_COLAB = "google.colab" in sys.modules
REPO = "boe-financial-analysis"

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive", force_remount=False)
    if not pathlib.Path(f"/content/{REPO}").exists():
        subprocess.run(["git", "clone", "-q",
                        f"https://github.com/maybebool/{REPO}.git",
                        f"/content/{REPO}"], check=True)
    ROOT = pathlib.Path(f"/content/{REPO}")
    DATA = pathlib.Path("/content/drive/MyDrive/boe-data")
else:
    ROOT = pathlib.Path.cwd()
    while not (ROOT / "requirements.txt").exists() and ROOT != ROOT.parent:
        ROOT = ROOT.parent
    DATA = ROOT / "data"

sys.path.insert(0, str(ROOT))
subprocess.run(["git", "-C", str(ROOT), "fetch", "-q", "origin"], check=False)
subprocess.run(["git", "-C", str(ROOT), "merge", "-q", "origin/main", "-m", "sync"],
               check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r",
                str(ROOT / "requirements.txt")], check=True)

from notebooks.env_cell import verify, check_python
check_python()
try:
    verify(ROOT)
except RuntimeError as e:
    print(e)
    print("\n Runtime -> Restart session, then run this cell again.")
    raise

import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from src import loading

print(f"ok  python {sys.version.split()[0]}  pandas {pd.__version__}  data {DATA}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ok  python 3.13.15  pandas 2.2.3  data /content/drive/MyDrive/boe-data

# %%
print("exports:", loading.exports(DATA))
print("files:  ", loading.files(DATA, loading.LATEST))
print("banks:  ", loading.firms(DATA, loading.LATEST))
# Out:
# exports: ['2026-09-13', 'Never ever upload or change something in the folder above']
# files:   []
# banks:   []

# %%
EXPORT = "2026-09-13"  # pin the export this notebook was written against

sentences_df = loading.load(DATA, "all_sentences.csv", EXPORT)
# Out:
# loaded all_sentences.csv  9519 rows

# %%
sentences_df
# Out:
#      bank  quarter call_type   call_date  position_in_call   section  \
# 0     JPM  2023-Q1  earnings  2023-04-14                 1  prepared
# 1     JPM  2023-Q1  earnings  2023-04-14                 1  prepared
# 2     JPM  2023-Q1  earnings  2023-04-14                 1  prepared
# 3     JPM  2023-Q1  earnings  2023-04-14                 1  prepared
# 4     JPM  2023-Q1  earnings  2023-04-14                 1  prepared
# ...   ...      ...       ...         ...               ...       ...
# 9514  UBS  2024-Q4  earnings  2025-02-04                60        qa
# 9515  UBS  2024-Q4  earnings  2025-02-04                60        qa
# 9516  UBS  2024-Q4  earnings  2025-02-04                60        qa
# 9517  UBS  2024-Q4  earnings  2025-02-04                60        qa
# 9518  UBS  2024-Q4  earnings  2025-02-04                60        qa
#
#      speaker_role       speaker_name speaker_institution  sentence_id  \
# 0        operator           Operator                 NaN         9789
# 1        operator           Operator                 NaN         9790
# 2        operator           Operator                 NaN         9791
# 3        operator           Operator                 NaN         9792
# 4        operator           Operator                 NaN         9793
# ...           ...                ...                 ...          ...
# 9514   management  Sergio P. Ermotti                 NaN         9784
# 9515   management  Sergio P. Ermotti                 NaN         9785
# 9516   management  Sergio P. Ermotti                 NaN         9786
# 9517   management  Sergio P. Ermotti                 NaN         9787
# 9518   management  Sergio P. Ermotti                 NaN         9788
#
#       sentence_number                                           sentence
# 0                   1                Good morning, ladies and gentlemen.
# 1                   2  Welcome to JPMorgan Chase’s First Quarter 2023...
# 2                   3                       This call is being recorded.
# 3                   4  Your line will be muted for the duration of th...
# 4                   5           We will now go live to the presentation.
# ...               ...                                                ...
# 9514                2                    So there are no more questions.
# 9515                3                       There are no more questions.
# 9516                4  So thank you for calling in and for your quest...
# 9517                5                   So I'll touch base next quarter.
# 9518                6                                         Thank you.
#
# [9519 rows x 12 columns]
