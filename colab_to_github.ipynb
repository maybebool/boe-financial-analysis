# %% [markdown]
# <a href="https://colab.research.google.com/github/maybebool/boe-financial-analysis/blob/roman/colab_to_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import subprocess
subprocess.run(["git", "clone", "-q",
                "https://github.com/maybebool/boe-financial-analysis.git",
                "/content/boe-financial-analysis"], check=True)
# Out:
# CompletedProcess(args=['git', 'clone', '-q', 'https://github.com/maybebool/boe-financial-analysis.git', '/content/boe-financial-analysis'], returncode=0)

# %%
# %cd /content/boe-financial-analysis
# !git checkout roman
# Out:
# /content/boe-financial-analysis
# Branch 'roman' set up to track remote branch 'roman' from 'origin'.
# Switched to a new branch 'roman'
